# %%
import numpy as np
import pandas as pd
import keras
import matplotlib.pyplot as plt

import glob
import random
import datetime
import tensorflow as tf
import numpy as np
import sklearn as sk
from tensorflow import keras
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras import backend as K
from tensorflow.keras import layers
from tensorflow.keras.layers import  Lambda, Dense, Dropout, BatchNormalization, Activation, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.layers import Reshape, Conv2DTranspose
from tensorflow.keras.utils import to_categorical,plot_model
from tensorflow.keras.losses import mse, binary_crossentropy
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix
from shutil import rmtree
from keras.models import load_model
from os.path import join, getctime, basename
from models import *
from utils import *
from data_preprocess import load_prep_data

# %load_ext autoreload
# %autoreload 2

aug_data = load_prep_data(time=500, debug=True, pooling = True, subsample = 2, average = 2, normalization = False, noise_level = 0.5)
x_train = aug_data['x_train']
y_train = aug_data['y_train']
x_valid = aug_data['x_valid']
y_valid = aug_data['y_valid']
x_test = aug_data['x_test']
y_test = aug_data['y_test']

x_train = tf.transpose(x_train, perm=[0, 2, 1])
x_valid = tf.transpose(x_valid, perm=[0, 2, 1])
x_test = tf.transpose(x_test, perm=[0, 2, 1])

print('Shape of training set after dimension reshaping:',x_train.shape)
print('Shape of validation set after dimension reshaping:',x_valid.shape)
print('Shape of test set after dimension reshaping:',x_test.shape)
# Out:
# Shape of x_train set: (7191, 22, 250)
# Shape of y_train labels: (7191, 4)
# Shape of x_valid set: (1269, 22, 250)
# Shape of y_valid labels: (1269, 4)
# Shape of x_test set: (1772, 22, 250)
# Shape of y_test labels: (1772, 4)
# Shape of x_train_valid set: (8460, 22, 250)
# Shape of y_train_valid labels: (8460, 4)
# Shape of training set after dimension reshaping: (7191, 250, 22)
# Shape of validation set after dimension reshaping: (1269, 250, 22)
# Shape of test set after dimension reshaping: (1772, 250, 22)

# %%
# from https://keras.io/examples/generative/vae/
class Sampling(layers.Layer):
    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# %%
# from https://keras.io/examples/generative/vae/
class VAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super(VAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(
            name="reconstruction_loss"
        )
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")
        #self.accuracy_tracker = keras.metrics.Accuracy(name = 'accuracy')

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
            #self.accuracy_tracker        
        ]

    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            
            reconstruction_loss = tf.reduce_mean(
                keras.losses.binary_crossentropy(tf.reshape(data, (-1, 22)), tf.reshape(reconstruction, (-1, 22)))
            )
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var + 1e-7))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            total_loss = reconstruction_loss + kl_loss
            #accuracy = self.accuracy_tracker.result()
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        #self.accuracy_tracker().update_state(accuracy)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
            #"accuracy":self.accuracy_tracker.result()
        }

# %%
latent_dim = 10
vae_filts1 = 100

## Build Encoder with GRU
encoder_inputs = keras.Input(shape=(250, 22))
x = layers.Conv1D(vae_filts1, 10, strides=2, activation="relu", padding='same')(encoder_inputs)
x = layers.GRU(64, return_sequences=False)(x)  # Adjust GRU output based on the need
x = layers.Dense(16, activation="relu")(x)

z_mean = layers.Dense(latent_dim, name="z_mean")(x)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(x)
z_log_var += 1e-8  # Ensure numerical stability
z = Sampling()([z_mean, z_log_var])

encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
encoder.summary()

## Build the decoder with GRU
latent_inputs = keras.Input(shape=(latent_dim,))
x = layers.Dense(64 * 250, activation="relu")(latent_inputs)  # Adjusted for GRU input
x = layers.Reshape((250, 64))(x)  # Adjust shape for GRU input
x = layers.GRU(64, return_sequences=True)(x)
x = layers.TimeDistributed(layers.Dense(22))(x)  # TimeDistributed wrapper for output

decoder = keras.Model(latent_inputs, x, name="decoder")
decoder.summary()

vae = VAE(encoder, decoder)
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 250, 22)]            0         []
#
#  conv1d (Conv1D)             (None, 125, 100)             22100     ['input_1[0][0]']
#
#  gru (GRU)                   (None, 64)                   31872     ['conv1d[0][0]']
#
#  dense (Dense)               (None, 16)                   1040      ['gru[0][0]']
#
#  z_log_var (Dense)           (None, 10)                   170       ['dense[0][0]']
#
#  z_mean (Dense)              (None, 10)                   170       ['dense[0][0]']
#
#  tf.__operators__.add (TFOp  (None, 10)                   0         ['z_log_var[0][0]']
#  Lambda)
#
#  sampling (Sampling)         (None, 10)                   0         ['z_mean[0][0]',
#                                                                      'tf.__operators__.add[0][0]']
#
# ==================================================================================================
# Total params: 55352 (216.22 KB)
# Trainable params: 55352 (216.22 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 10)]              0
#
#  dense_1 (Dense)             (None, 16000)             176000
#
#  reshape (Reshape)           (None, 250, 64)           0
#
#  gru_1 (GRU)                 (None, 250, 64)           24960
#
#  time_distributed (TimeDist  (None, 250, 22)           1430
#  ributed)
#
# =================================================================
# Total params: 202390 (790.59 KB)
# Trainable params: 202390 (790.59 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
learning_rate = 1e-3
decay = 1e-6
vae_optimizer = keras.optimizers.legacy.Adam(learning_rate=learning_rate, decay = decay, clipvalue=0.5)
vae.compile(optimizer=vae_optimizer)

print("x_train.shape {}".format(x_train.shape))
vae.fit(x_train, epochs = 30, batch_size=128, verbose = True)
# Out:
# x_train.shape (7191, 250, 22)
# Epoch 1/30
# 57/57 [==============================] - 13s 203ms/step - loss: 4.2556 - reconstruction_loss: 0.9647 - kl_loss: 0.4325
# Epoch 2/30
# 57/57 [==============================] - 12s 202ms/step - loss: -4.9243 - reconstruction_loss: -9.0942 - kl_loss: 0.4774
# Epoch 3/30
# 57/57 [==============================] - 12s 206ms/step - loss: -19.9130 - reconstruction_loss: -21.2769 - kl_loss: 0.4930
# Epoch 4/30
# 57/57 [==============================] - 13s 220ms/step - loss: -21.9153 - reconstruction_loss: -22.6451 - kl_loss: 0.2884
# Epoch 5/30
# 57/57 [==============================] - 12s 219ms/step - loss: -23.0624 - reconstruction_loss: -23.3642 - kl_loss: 0.5601
# Epoch 6/30
# 57/57 [==============================] - 12s 210ms/step - loss: -23.5361 - reconstruction_loss: -24.6034 - kl_loss: 0.7011
# Epoch 7/30
# 57/57 [==============================] - 12s 208ms/step - loss: -24.0234 - reconstruction_loss: -24.7767 - kl_loss: 0.7387
# Epoch 8/30
# 57/57 [==============================] - 12s 215ms/step - loss: -24.7167 - reconstruction_loss: -25.4395 - kl_loss: 0.7557
# Epoch 9/30
# 57/57 [==============================] - 12s 205ms/step - loss: -24.2132 - reconstruction_loss: -25.3531 - kl_loss: 0.8603
# Epoch 10/30
# 57/57 [==============================] - 12s 212ms/step - loss: -24.7472 - reconstruction_loss: -25.6266 - kl_loss: 0.7871
# Epoch 11/30
# 57/57 [==============================] - 12s 219ms/step - loss: -24.5966 - reconstruction_loss: -25.8138 - kl_loss: 0.7428
# Epoch 12/30
# 57/57 [==============================] - 12s 214ms/step - loss: -25.0674 - reconstruction_loss: -25.9067 - kl_loss: 0.7392
# Epoch 13/30
# 57/57 [==============================] - 12s 213ms/step - loss: -25.3041 - reconstruction_loss: -25.8312 - kl_loss: 0.7444
# Epoch 14/30
# 57/57 [==============================] - 12s 217ms/step - loss: -25.4638 - reconstruction_loss: -25.9260 - kl_loss: 0.8812
# Epoch 15/30
# 57/57 [==============================] - 12s 205ms/step - loss: -25.2875 - reconstruction_loss: -26.3073 - kl_loss: 0.9247
# Epoch 16/30
# 57/57 [==============================] - 12s 218ms/step - loss: -25.5623 - reconstruction_loss: -25.8634 - kl_loss: 0.7171
# Epoch 17/30
# 57/57 [==============================] - 12s 215ms/step - loss: -25.0690 - reconstruction_loss: -25.5378 - kl_loss: 0.5532
# Epoch 18/30
# 57/57 [==============================] - 12s 208ms/step - loss: -25.1306 - reconstruction_loss: -26.2718 - kl_loss: 0.7582
# Epoch 19/30
# 57/57 [==============================] - 12s 215ms/step - loss: -25.4080 - reconstruction_loss: -26.1310 - kl_loss: 0.7994
# Epoch 20/30
# 57/57 [==============================] - 12s 209ms/step - loss: -26.1278 - reconstruction_loss: -26.6239 - kl_loss: 0.8341
# Epoch 21/30
# 57/57 [==============================] - 12s 213ms/step - loss: -26.1330 - reconstruction_loss: -26.8040 - kl_loss: 0.8275
# Epoch 22/30
# 57/57 [==============================] - 12s 219ms/step - loss: -25.9935 - reconstruction_loss: -26.4858 - kl_loss: 0.7234
# Epoch 23/30
# 57/57 [==============================] - 12s 205ms/step - loss: -26.1816 - reconstruction_loss: -26.9237 - kl_loss: 0.8198
# Epoch 24/30
# 57/57 [==============================] - 13s 219ms/step - loss: -26.2588 - reconstruction_loss: -27.4422 - kl_loss: 0.8418
# Epoch 25/30
# 57/57 [==============================] - 12s 202ms/step - loss: -26.1739 - reconstruction_loss: -26.5701 - kl_loss: 0.7887
# Epoch 26/30
# 57/57 [==============================] - 12s 214ms/step - loss: -25.9645 - reconstruction_loss: -26.4816 - kl_loss: 0.7472
# Epoch 27/30
# 57/57 [==============================] - 12s 210ms/step - loss: -25.9710 - reconstruction_loss: -26.5547 - kl_loss: 0.8092
# Epoch 28/30
# 57/57 [==============================] - 13s 227ms/step - loss: -26.9680 - reconstruction_loss: -27.1646 - kl_loss: 0.7520
# Epoch 29/30
# 57/57 [==============================] - 12s 217ms/step - loss: -25.7538 - reconstruction_loss: -26.1411 - kl_loss: 0.6429
# Epoch 30/30
# 57/57 [==============================] - 13s 221ms/step - loss: -25.6768 - reconstruction_loss: -26.5866 - kl_loss: 0.7973

# %%
#Passing real data through VAE to generate "fake" data
z_sample = vae.encoder([x_train])[2]
x_decoded = vae.decoder([z_sample])

# %%
# print(x_train)
x_tane = tf.reshape(x_train, (x_train.shape[0], 250, 22))
print('Before VAE')
plt.plot(x_tane[7])
plt.show()

print('After VAE:')
x_vae = np.array(x_decoded).reshape(x_decoded.shape[0], 250, 22)
plt.plot(x_vae[1])
plt.show()

#Adding fake image data to existing real data
x_train3 = np.concatenate((x_train, x_decoded), axis = 0)
y_train3 = np.concatenate((y_train, y_train), axis = 0)
print("x_train3.shape {} y_train3.shape {}".format(x_train3.shape, y_train3.shape))
# Out:
# Before VAE
# After VAE:
# x_train3.shape (14382, 250, 22) y_train3.shape (14382, 4)

# %%
x_train_transposed = tf.transpose(tf.expand_dims(x_train3, axis=-1), perm=[0, 1, 3, 2])
x_valid_transposed = tf.transpose(tf.expand_dims(x_valid, axis=-1), perm=[0, 1, 3, 2])
x_test_transposed = tf.transpose(tf.expand_dims(x_test, axis=-1), perm=[0, 1, 3, 2])

input_shape = x_train_transposed.shape
print("x_train_transposed.shape: {}", format(x_train_transposed.shape))

config = {
    # Network
    'num_inputs': input_shape[0],
    'input_shape': (input_shape[1], 1, input_shape[3]), # (250, 1, 22)
    'epochs': 100,
    'dropout': 0.5,
    'batch_size': 64
}
model = CNN4LayerGRU()
model.build_model(config)
history = model.train(x_train_transposed, y_train3, x_valid_transposed, y_valid, config, get_workpath('CNN4LayerGRU'))

raw = model.evaluate(x_test_transposed, y_test)
print("Raw Acc result: {}".format(raw[1]))
# Out:
# x_train_transposed.shape: {} (14382, 250, 1, 22)
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_24 (Conv2D)          (None, 250, 1, 25)        13775
#
#  max_pooling2d_24 (MaxPooli  (None, 84, 1, 25)         0
#  ng2D)
#
#  batch_normalization_24 (Ba  (None, 84, 1, 25)         100
#  tchNormalization)
#
#  dropout_36 (Dropout)        (None, 84, 1, 25)         0
#
#  conv2d_25 (Conv2D)          (None, 84, 1, 50)         31300
#
#  max_pooling2d_25 (MaxPooli  (None, 28, 1, 50)         0
#  ng2D)
#
#  batch_normalization_25 (Ba  (None, 28, 1, 50)         200
#  tchNormalization)
#
#  dropout_37 (Dropout)        (None, 28, 1, 50)         0
#
#  conv2d_26 (Conv2D)          (None, 28, 1, 100)        125100
#
#  max_pooling2d_26 (MaxPooli  (None, 10, 1, 100)        0
#  ng2D)
#
#  batch_normalization_26 (Ba  (None, 10, 1, 100)        400
#  tchNormalization)
#
#  dropout_38 (Dropout)        (None, 10, 1, 100)        0
#
#  conv2d_27 (Conv2D)          (None, 10, 1, 200)        500200
#
#  max_pooling2d_27 (MaxPooli  (None, 4, 1, 200)         0
#  ng2D)
#
#  batch_normalization_27 (Ba  (None, 4, 1, 200)         800
#  tchNormalization)
#
#  dropout_39 (Dropout)        (None, 4, 1, 200)         0
#
#  flatten_12 (Flatten)        (None, 800)               0
#
#  reshape_7 (Reshape)         (None, 200, 4)            0
#
#  gru_8 (GRU)                 (None, 200, 44)           6600
#
#  dropout_40 (Dropout)        (None, 200, 44)           0
#
#  flatten_13 (Flatten)        (None, 8800)              0
#
#  dense_15 (Dense)            (None, 64)                563264
#
#  dropout_41 (Dropout)        (None, 64)                0
#
#  dense_16 (Dense)            (None, 4)                 260
#
# =================================================================
# Total params: 1241999 (4.74 MB)
# Trainable params: 1241249 (4.73 MB)
# Non-trainable params: 750 (2.93 KB)
# _________________________________________________________________
# Model compiled.
# Epoch 1/100
# 225/225 [==============================] - 15s 63ms/step - loss: 1.7139 - accuracy: 0.2724 - val_loss: 1.3560 - val_accuracy: 0.3641
# Epoch 2/100
# 225/225 [==============================] - 14s 63ms/step - loss: 1.3548 - accuracy: 0.3214 - val_loss: 1.2614 - val_accuracy: 0.4184
# Epoch 3/100
# 225/225 [==============================] - 14s 62ms/step - loss: 1.3227 - accuracy: 0.3373 - val_loss: 1.2013 - val_accuracy: 0.4665
# Epoch 4/100
# 225/225 [==============================] - 14s 62ms/step - loss: 1.3080 - accuracy: 0.3511 - val_loss: 1.1706 - val_accuracy: 0.4901
# Epoch 5/100
# 225/225 [==============================] - 14s 63ms/step - loss: 1.3004 - accuracy: 0.3518 - val_loss: 1.1471 - val_accuracy: 0.5122
# Epoch 6/100
# 225/225 [==============================] - 14s 62ms/step - loss: 1.2852 - accuracy: 0.3716 - val_loss: 1.1272 - val_accuracy: 0.5272
# Epoch 7/100
# 225/225 [==============================] - 14s 62ms/step - loss: 1.2640 - accuracy: 0.3876 - val_loss: 1.0824 - val_accuracy: 0.5335
# Epoch 8/100
# 225/225 [==============================] - 14s 62ms/step - loss: 1
# 225/225 [==============================] - 15s 66ms/step - loss: 1.0434 - accuracy: 0.4993 - val_loss: 0.5089 - val_accuracy: 0.8605
# Epoch 98/100
# 225/225 [==============================] - 15s 66ms/step - loss: 1.0321 - accuracy: 0.4994 - val_loss: 0.5143 - val_accuracy: 0.8377
# Epoch 99/100
# 225/225 [==============================] - 15s 66ms/step - loss: 1.0433 - accuracy: 0.4916 - val_loss: 0.5023 - val_accuracy: 0.8605
# Epoch 100/100
# 225/225 [==============================] - 15s 66ms/step - loss: 1.0342 - accuracy: 0.4971 - val_loss: 0.4784 - val_accuracy: 0.8621
# 56/56 [==============================] - 1s 12ms/step - loss: 0.7484 - accuracy: 0.7190
# Raw Acc result: 0.7189615964889526

# %%
x_train_transposed = tf.transpose(tf.expand_dims(x_train, axis=-1), perm=[0, 1, 3, 2])
x_valid_transposed = tf.transpose(tf.expand_dims(x_valid, axis=-1), perm=[0, 1, 3, 2])
x_test_transposed = tf.transpose(tf.expand_dims(x_test, axis=-1), perm=[0, 1, 3, 2])

input_shape = x_train_transposed.shape
print("x_train_transposed.shape: {}", format(x_train_transposed.shape))

config = {
    # Network
    'num_inputs': input_shape[0],
    'input_shape': (input_shape[1], 1, input_shape[3]), # (250, 1, 22)
    'epochs': 100,
    'dropout': 0.5,
    'batch_size': 64
}
model = CNN4LayerGRU()
model.build_model(config)
history = model.train(x_train_transposed, y_train, x_valid_transposed, y_valid, config, get_workpath('CNN4LayerGRU'))

raw = model.evaluate(x_test_transposed, y_test)
print("Raw Acc result: {}".format(raw[1]))
# Out:
# x_train_transposed.shape: {} (7191, 250, 1, 22)
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_28 (Conv2D)          (None, 250, 1, 25)        13775
#
#  max_pooling2d_28 (MaxPooli  (None, 84, 1, 25)         0
#  ng2D)
#
#  batch_normalization_28 (Ba  (None, 84, 1, 25)         100
#  tchNormalization)
#
#  dropout_42 (Dropout)        (None, 84, 1, 25)         0
#
#  conv2d_29 (Conv2D)          (None, 84, 1, 50)         31300
#
#  max_pooling2d_29 (MaxPooli  (None, 28, 1, 50)         0
#  ng2D)
#
#  batch_normalization_29 (Ba  (None, 28, 1, 50)         200
#  tchNormalization)
#
#  dropout_43 (Dropout)        (None, 28, 1, 50)         0
#
#  conv2d_30 (Conv2D)          (None, 28, 1, 100)        125100
#
#  max_pooling2d_30 (MaxPooli  (None, 10, 1, 100)        0
#  ng2D)
#
#  batch_normalization_30 (Ba  (None, 10, 1, 100)        400
#  tchNormalization)
#
#  dropout_44 (Dropout)        (None, 10, 1, 100)        0
#
#  conv2d_31 (Conv2D)          (None, 10, 1, 200)        500200
#
#  max_pooling2d_31 (MaxPooli  (None, 4, 1, 200)         0
#  ng2D)
#
#  batch_normalization_31 (Ba  (None, 4, 1, 200)         800
#  tchNormalization)
#
#  dropout_45 (Dropout)        (None, 4, 1, 200)         0
#
#  flatten_14 (Flatten)        (None, 800)               0
#
#  reshape_8 (Reshape)         (None, 200, 4)            0
#
#  gru_9 (GRU)                 (None, 200, 44)           6600
#
#  dropout_46 (Dropout)        (None, 200, 44)           0
#
#  flatten_15 (Flatten)        (None, 8800)              0
#
#  dense_17 (Dense)            (None, 64)                563264
#
#  dropout_47 (Dropout)        (None, 64)                0
#
#  dense_18 (Dense)            (None, 4)                 260
#
# =================================================================
# Total params: