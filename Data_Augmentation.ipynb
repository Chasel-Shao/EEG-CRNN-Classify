# %%
import numpy as np
import pandas as pd
import keras
import matplotlib.pyplot as plt

import glob
import random
import tensorflow as tf
from shutil import rmtree
from keras.models import load_model
from os.path import join, getctime, basename
from models import *
from utils import *
from data_preprocess import *

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def test_model(aug_data, model):
    test_CNN4LayerGRU(aug_data, model)

# model = CNN4LayerGRU()
# model = VanillaRNN()

# %% [markdown]
# # No processing

# %%
# No processing
aug_data = load_prep_data(time=1000, debug=False, pooling = False, subsample = 1, average = 1, noise_level = 0)
test_model(aug_data, CNN4LayerGRU())
# Out:
# x_train.shape: {} (1798, 1000, 1, 22)
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_4 (Conv2D)           (None, 1000, 1, 25)       13775
#
#  max_pooling2d_4 (MaxPoolin  (None, 334, 1, 25)        0
#  g2D)
#
#  batch_normalization_4 (Bat  (None, 334, 1, 25)        100
#  chNormalization)
#
#  dropout_15 (Dropout)        (None, 334, 1, 25)        0
#
#  conv2d_5 (Conv2D)           (None, 334, 1, 50)        31300
#
#  max_pooling2d_5 (MaxPoolin  (None, 112, 1, 50)        0
#  g2D)
#
#  batch_normalization_5 (Bat  (None, 112, 1, 50)        200
#  chNormalization)
#
#  dropout_16 (Dropout)        (None, 112, 1, 50)        0
#
#  conv2d_6 (Conv2D)           (None, 112, 1, 100)       125100
#
#  max_pooling2d_6 (MaxPoolin  (None, 38, 1, 100)        0
#  g2D)
#
#  batch_normalization_6 (Bat  (None, 38, 1, 100)        400
#  chNormalization)
#
# ...

# %% [markdown]
# # Normalization

# %%
# Normalization
aug_data = load_prep_data(time=1000, debug=False, pooling = False, subsample = 1, average = 1, normalization = True, noise_level = 0, windowing = True)
test_model(aug_data, CNN4LayerGRU())
# Out:
# x_train.shape: {} (10787, 500, 1, 22)
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_8 (Conv2D)           (None, 500, 1, 25)        13775
#
#  max_pooling2d_8 (MaxPoolin  (None, 167, 1, 25)        0
#  g2D)
#
#  batch_normalization_8 (Bat  (None, 167, 1, 25)        100
#  chNormalization)
#
#  dropout_21 (Dropout)        (None, 167, 1, 25)        0
#
#  conv2d_9 (Conv2D)           (None, 167, 1, 50)        31300
#
#  max_pooling2d_9 (MaxPoolin  (None, 56, 1, 50)         0
#  g2D)
#
#  batch_normalization_9 (Bat  (None, 56, 1, 50)         200
#  chNormalization)
#
#  dropout_22 (Dropout)        (None, 56, 1, 50)         0
#
#  conv2d_10 (Conv2D)          (None, 56, 1, 100)        125100
#
#  max_pooling2d_10 (MaxPooli  (None, 19, 1, 100)        0
#  ng2D)
#
#  batch_normalization_10 (Ba  (None, 19, 1, 100)        400
#  tchNormalization)
#
# ...

# %% [markdown]
# # Windowing

# %%
aug_data = load_prep_data(time=1000, debug=False, pooling = False, subsample = 1, average = 1, noise_level = 0, windowing = True)
test_model(aug_data, CNN4LayerGRU())
# Out:
# x_train.shape: {} (10787, 500, 1, 22)
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_12 (Conv2D)          (None, 500, 1, 25)        13775
#
#  max_pooling2d_12 (MaxPooli  (None, 167, 1, 25)        0
#  ng2D)
#
#  batch_normalization_12 (Ba  (None, 167, 1, 25)        100
#  tchNormalization)
#
#  dropout_27 (Dropout)        (None, 167, 1, 25)        0
#
#  conv2d_13 (Conv2D)          (None, 167, 1, 50)        31300
#
#  max_pooling2d_13 (MaxPooli  (None, 56, 1, 50)         0
#  ng2D)
#
#  batch_normalization_13 (Ba  (None, 56, 1, 50)         200
#  tchNormalization)
#
#  dropout_28 (Dropout)        (None, 56, 1, 50)         0
#
#  conv2d_14 (Conv2D)          (None, 56, 1, 100)        125100
#
#  max_pooling2d_14 (MaxPooli  (None, 19, 1, 100)        0
#  ng2D)
#
#  batch_normalization_14 (Ba  (None, 19, 1, 100)        400
#  tchNormalization)
#
# ...

# %% [markdown]
# # Trimming

# %%
# Trimming
aug_data = load_prep_data(time=500, debug=False, pooling = False, subsample = 1, average = 1, noise_level = 0)
test_model(aug_data, CNN4LayerGRU())
# Out:
# x_train.shape: {} (1798, 500, 1, 22)
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_16 (Conv2D)          (None, 500, 1, 25)        13775
#
#  max_pooling2d_16 (MaxPooli  (None, 167, 1, 25)        0
#  ng2D)
#
#  batch_normalization_16 (Ba  (None, 167, 1, 25)        100
#  tchNormalization)
#
#  dropout_33 (Dropout)        (None, 167, 1, 25)        0
#
#  conv2d_17 (Conv2D)          (None, 167, 1, 50)        31300
#
#  max_pooling2d_17 (MaxPooli  (None, 56, 1, 50)         0
#  ng2D)
#
#  batch_normalization_17 (Ba  (None, 56, 1, 50)         200
#  tchNormalization)
#
#  dropout_34 (Dropout)        (None, 56, 1, 50)         0
#
#  conv2d_18 (Conv2D)          (None, 56, 1, 100)        125100
#
#  max_pooling2d_18 (MaxPooli  (None, 19, 1, 100)        0
#  ng2D)
#
#  batch_normalization_18 (Ba  (None, 19, 1, 100)        400
#  tchNormalization)
#
# ...

# %% [markdown]
# # Pooling

# %%
# pooling 
aug_data = load_prep_data(time=1000, debug=False, pooling = True, subsample = 1, average = 2, noise_level = 0)
test_model(aug_data, CNN4LayerGRU())
# Out:
# x_train.shape: {} (3596, 500, 1, 22)
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_20 (Conv2D)          (None, 500, 1, 25)        13775
#
#  max_pooling2d_20 (MaxPooli  (None, 167, 1, 25)        0
#  ng2D)
#
#  batch_normalization_20 (Ba  (None, 167, 1, 25)        100
#  tchNormalization)
#
#  dropout_39 (Dropout)        (None, 167, 1, 25)        0
#
#  conv2d_21 (Conv2D)          (None, 167, 1, 50)        31300
#
#  max_pooling2d_21 (MaxPooli  (None, 56, 1, 50)         0
#  ng2D)
#
#  batch_normalization_21 (Ba  (None, 56, 1, 50)         200
#  tchNormalization)
#
#  dropout_40 (Dropout)        (None, 56, 1, 50)         0
#
#  conv2d_22 (Conv2D)          (None, 56, 1, 100)        125100
#
#  max_pooling2d_22 (MaxPooli  (None, 19, 1, 100)        0
#  ng2D)
#
#  batch_normalization_22 (Ba  (None, 19, 1, 100)        400
#  tchNormalization)
#
# ...

# %% [markdown]
# # Subsampling

# %%
# Subsampling
aug_data = load_prep_data(time=1000, debug=False, pooling = False, subsample = 5, average = 1, noise_level = 0)
test_model(aug_data, CNN4LayerGRU())
# Out:
# x_train.shape: {} (8989, 200, 1, 22)
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_24 (Conv2D)          (None, 200, 1, 25)        13775
#
#  max_pooling2d_24 (MaxPooli  (None, 67, 1, 25)         0
#  ng2D)
#
#  batch_normalization_24 (Ba  (None, 67, 1, 25)         100
#  tchNormalization)
#
#  dropout_45 (Dropout)        (None, 67, 1, 25)         0
#
#  conv2d_25 (Conv2D)          (None, 67, 1, 50)         31300
#
#  max_pooling2d_25 (MaxPooli  (None, 23, 1, 50)         0
#  ng2D)
#
#  batch_normalization_25 (Ba  (None, 23, 1, 50)         200
#  tchNormalization)
#
#  dropout_46 (Dropout)        (None, 23, 1, 50)         0
#
#  conv2d_26 (Conv2D)          (None, 23, 1, 100)        125100
#
#  max_pooling2d_26 (MaxPooli  (None, 8, 1, 100)         0
#  ng2D)
#
#  batch_normalization_26 (Ba  (None, 8, 1, 100)         400
#  tchNormalization)
#
# ...

# %% [markdown]
# # Gaussian Noise

# %%
# Gaussian Noise
aug_data = load_prep_data(time=1000, debug=False, pooling = False, subsample = 1, average = 1, noise_level = 0.5)
test_model(aug_data, CNN4LayerGRU())
# Out:
# x_train.shape: {} (1798, 1000, 1, 22)
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_28 (Conv2D)          (None, 1000, 1, 25)       13775
#
#  max_pooling2d_28 (MaxPooli  (None, 334, 1, 25)        0
#  ng2D)
#
#  batch_normalization_28 (Ba  (None, 334, 1, 25)        100
#  tchNormalization)
#
#  dropout_51 (Dropout)        (None, 334, 1, 25)        0
#
#  conv2d_29 (Conv2D)          (None, 334, 1, 50)        31300
#
#  max_pooling2d_29 (MaxPooli  (None, 112, 1, 50)        0
#  ng2D)
#
#  batch_normalization_29 (Ba  (None, 112, 1, 50)        200
#  tchNormalization)
#
#  dropout_52 (Dropout)        (None, 112, 1, 50)        0
#
#  conv2d_30 (Conv2D)          (None, 112, 1, 100)       125100
#
#  max_pooling2d_30 (MaxPooli  (None, 38, 1, 100)        0
#  ng2D)
#
#  batch_normalization_30 (Ba  (None, 38, 1, 100)        400
#  tchNormalization)
#
# ...

# %% [markdown]
# # All method

# %%
# All method
aug_data = load_prep_data(time=500, debug=False, pooling = True, subsample = 2, average = 2, normalization = False, noise_level = 0.5)
test_model(aug_data, CNN4LayerGRU())
# Out:
# x_train.shape: {} (7191, 250, 1, 22)
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_32 (Conv2D)          (None, 250, 1, 25)        13775
#
#  max_pooling2d_32 (MaxPooli  (None, 84, 1, 25)         0
#  ng2D)
#
#  batch_normalization_32 (Ba  (None, 84, 1, 25)         100
#  tchNormalization)
#
#  dropout_57 (Dropout)        (None, 84, 1, 25)         0
#
#  conv2d_33 (Conv2D)          (None, 84, 1, 50)         31300
#
#  max_pooling2d_33 (MaxPooli  (None, 28, 1, 50)         0
#  ng2D)
#
#  batch_normalization_33 (Ba  (None, 28, 1, 50)         200
#  tchNormalization)
#
#  dropout_58 (Dropout)        (None, 28, 1, 50)         0
#
#  conv2d_34 (Conv2D)          (None, 28, 1, 100)        125100
#
#  max_pooling2d_34 (MaxPooli  (None, 10, 1, 100)        0
#  ng2D)
#
#  batch_normalization_34 (Ba  (None, 10, 1, 100)        400
#  tchNormalization)
#
# ...
