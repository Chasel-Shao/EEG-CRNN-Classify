# %%
import numpy as np
import pandas as pd
import keras
import matplotlib.pyplot as plt

import glob
import random
import datetime
import tensorflow as tf
from shutil import rmtree
from keras.models import load_model
from os.path import join, getctime, basename
from models import *
from utils import *
from data_preprocess import load_prep_data

# %load_ext autoreload
# %autoreload 2

aug_data = load_prep_data(time=500, debug=True, onehot=True)
x_train = aug_data['x_train']
y_train = aug_data['y_train']
x_valid = aug_data['x_valid']
y_valid = aug_data['y_valid']
x_test = aug_data['x_test']
y_test = aug_data['y_test']
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Shape of x_train set: (6960, 22, 250)
# Shape of y_train labels: (6960,)
# Shape of x_valid set: (1500, 22, 250)
# Shape of y_valid labels: (1500,)
# Shape of X_test_prep set: (1772, 22, 250)
# Shape of y_test_prep labels: (1772,)
# Shape of y_train labels after categorical conversion: (6960, 4)
# Shape of y_valid labels after categorical conversion: (1500, 4)
# Shape of y_test labels after categorical conversion: (1772, 4)

# %%
input_shape = x_train.shape
x_train = tf.transpose( tf.expand_dims(x_train, axis=-1), perm=[0, 2, 3, 1])
x_valid = tf.transpose( tf.expand_dims(x_valid, axis=-1), perm=[0, 2, 3, 1])

print("x_train.shape: {}", format(x_train.shape))
# Out:
# x_train.shape: {} (6960, 250, 1, 22)

# %%
config = {
    # Network
    'num_inputs': x_train.shape[0],
    'input_shape': (input_shape[2],1, input_shape[1]),
    'epochs': 100,
    'dropout': 0.5,
    'batch_size': 128
}
ConvLSTM= ConvLSTM()
ConvLSTM.build_model(config)
history = ConvLSTM.train(x_train, y_train, x_valid, y_valid, config, get_workpath('ConvLSTMAvgPool'))
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_20 (Conv2D)          (None, 250, 1, 25)        13775
#
#  max_pooling2d_10 (MaxPooli  (None, 84, 1, 25)         0
#  ng2D)
#
#  batch_normalization_20 (Ba  (None, 84, 1, 25)         100
#  tchNormalization)
#
#  dropout_20 (Dropout)        (None, 84, 1, 25)         0
#
#  conv2d_21 (Conv2D)          (None, 84, 1, 50)         31300
#
#  average_pooling2d_10 (Aver  (None, 28, 1, 50)         0
#  agePooling2D)
#
#  batch_normalization_21 (Ba  (None, 28, 1, 50)         200
#  tchNormalization)
#
#  dropout_21 (Dropout)        (None, 28, 1, 50)         0
#
#  conv2d_22 (Conv2D)          (None, 28, 1, 100)        125100
#
#  max_pooling2d_11 (MaxPooli  (None, 10, 1, 100)        0
#  ng2D)
#
#  batch_normalization_22 (Ba  (None, 10, 1, 100)        400
#  tchNormalization)
#
#  dropout_22 (Dropout)        (None, 10, 1, 100)        0
#
#  conv2d_23 (Conv2D)          (None, 10, 1, 200)        500200
#
#  average_pooling2d_11 (Aver  (None, 4, 1, 200)         0
#  agePooling2D)
#
#  batch_normalization_23 (Ba  (None, 4, 1, 200)         800
#  tchNormalization)
#
#  dropout_23 (Dropout)        (None, 4, 1, 200)         0
#
#  flatten_5 (Flatten)         (None, 800)               0
#
#  dense_10 (Dense)            (None, 40)                32040
#
#  reshape_5 (Reshape)         (None, 40, 1)             0
#
#  lstm_5 (LSTM)               (None, 10)                480
#
#  dense_11 (Dense)            (None, 4)                 44
#
# =================================================================
# Total params:
100
# 55/55 [==============================] - 6s 111ms/step - loss: 0.6692 - accuracy: 0.7457 - val_loss: 0.8095 - val_accuracy: 0.6813
# Epoch 84/100
# 55/55 [==============================] - 6s 109ms/step - loss: 0.6590 - accuracy: 0.7476 - val_loss: 0.7856 - val_accuracy: 0.6827
# Epoch 85/100
# 55/55 [==============================] - 6s 110ms/step - loss: 0.6647 - accuracy: 0.7507 - val_loss: 0.7871 - val_accuracy: 0.6980
# Epoch 86/100
# 55/55 [==============================] - 6s 109ms/step - loss: 0.6781 - accuracy: 0.7435 - val_loss: 0.7692 - val_accuracy: 0.7100
# Epoch 87/100
# 55/55 [==============================] - 6s 111ms/step - loss: 0.6568 - accuracy: 0.7526 - val_loss: 0.7746 - val_accuracy: 0.6913
# Epoch 88/100
# 55/55 [==============================] - 6s 107ms/step - loss: 0.6427 - accuracy: 0.7618 - val_loss: 0.8206 - val_accuracy: 0.6980
# Epoch 89/100
# 55/55 [==============================] - 7s 126ms/step - loss: 0.6572 - accuracy: 0.7526 - val_loss: 0.7726 - val_accuracy: 0.7073
# Epoch 90/100
# 55/55 [==============================] - 7s 121ms/step - loss: 0.6268 - accuracy: 0.7655 - val_loss: 0.7781 - val_accuracy: 0.6993
# Epoch 91/100
# 55/55 [==============================] - 6s 117ms/step - loss: 0.6456 - accuracy: 0.7578 - val_loss: 0.7892 - val_accuracy: 0.7053
# Epoch 92/100
# 55/55 [==============================] - 7s 121ms/step - loss: 0.6425 - accuracy: 0.7510 - val_loss: 0.7765 - val_accuracy: 0.7027
# Epoch 93/100
# 55/55 [==============================] - 7s 122ms/step - loss: 0.6232 - accuracy: 0.7664 - val_loss: 0.7607 - val_accuracy: 0.7060
# Epoch 94/100
# 55/55 [==============================] - 6s 117ms/step - loss: 0.6281 - accuracy: 0.7639 - val_loss: 0.8471 - val_accuracy: 0.6727
# Epoch 95/100
# 55/55 [==============================] - 6s 114ms/step - loss: 0.6299 - accuracy: 0.7602 - val_loss: 0.7940 - val_accuracy: 0.6960
# Epoch 96/100
# 55/55 [==============================] - 6s 112ms/step - loss: 0.6356 - accuracy: 0.7601 - val_loss: 0.7944 - val_accuracy: 0.6960
# Epoch 97/100
# 55/55 [==============================] - 8s 138ms/step - loss: 0.6199 - accuracy: 0.7645 - val_loss: 0.8283 - val_accuracy: 0.6840
# Epoch 98/100
# 55/55 [==============================] - 6s 116ms/step - loss: 0.6124 - accuracy: 0.7731 - val_loss: 0.8197 - val_accuracy: 0.6900
# Epoch 99/100
# 55/55 [==============================] - 6s 113ms/step - loss: 0.6289 - accuracy: 0.7611 - val_loss: 0.7819 - val_accuracy: 0.7047
# Epoch 100/100
# 55/55 [==============================] - 6s 117ms/step - loss: 0.6156 - accuracy: 0.7678 - val_loss: 0.8183 - val_accuracy: 0.6987

# %%
x_test_transposed = tf.transpose(tf.expand_dims(x_test, axis=-1), perm=[0, 2, 3, 1])
raw = ConvLSTM.evaluate(x_test_transposed, y_test)
print("Raw Acc result: {}".format(raw[1]))
replace_model_if_better('ConvLSTMAvgPool', np.mean(raw[1]), CNN4LayerLSTM, config)
# Out:
# 56/56 [==============================] - 1s 10ms/step - loss: 0.7506 - accuracy: 0.7116
# Raw Acc result: 0.7116252779960632
# Old model exists. Comparing performance.
# New model is better than the old one. Replacing the old model with the new model.
# True

# %%
plt.figure(figsize=(6, 4))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.figure(figsize=(6, 4))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
