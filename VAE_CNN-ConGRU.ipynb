# %%
import numpy as np
import pandas as pd
import keras
import matplotlib.pyplot as plt

import glob
import random
import datetime
import tensorflow as tf
import numpy as np
import sklearn as sk
from tensorflow import keras
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras import backend as K
from tensorflow.keras import layers
from tensorflow.keras.layers import  Lambda, Dense, Dropout, BatchNormalization, Activation, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.layers import Reshape, Conv2DTranspose
from tensorflow.keras.utils import to_categorical,plot_model
from tensorflow.keras.losses import mse, binary_crossentropy
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix
from shutil import rmtree
from keras.models import load_model
from os.path import join, getctime, basename
from models import *
from utils import *
from data_preprocess import load_prep_data

# %load_ext autoreload
# %autoreload 2

aug_data = load_prep_data(time=500, debug=True, pooling = True, subsample = 2, average = 2, normalization = False, noise_level = 0.5)
x_train = aug_data['x_train']
y_train = aug_data['y_train']
x_valid = aug_data['x_valid']
y_valid = aug_data['y_valid']
x_test = aug_data['x_test']
y_test = aug_data['y_test']

x_train = tf.transpose( tf.expand_dims(x_train, axis=-1), perm=[0, 2, 3, 1])
x_valid = tf.transpose( tf.expand_dims(x_valid, axis=-1), perm=[0, 2, 3, 1])
x_test = tf.transpose(tf.expand_dims(x_test, axis=-1), perm=[0, 2, 3, 1])

print('Shape of training set after dimension reshaping:',x_train.shape)
print('Shape of validation set after dimension reshaping:',x_valid.shape)
print('Shape of test set after dimension reshaping:',x_test.shape)
# Out:
# Shape of x_train set: (7191, 22, 250)
# Shape of y_train labels: (7191, 4)
# Shape of x_valid set: (1269, 22, 250)
# Shape of y_valid labels: (1269, 4)
# Shape of x_test set: (1772, 22, 250)
# Shape of y_test labels: (1772, 4)
# Shape of x_train_valid set: (8460, 22, 250)
# Shape of y_train_valid labels: (8460, 4)
# Shape of training set after dimension reshaping: (7191, 250, 1, 22)
# Shape of validation set after dimension reshaping: (1269, 250, 1, 22)
# Shape of test set after dimension reshaping: (1772, 250, 1, 22)

# %%
# from https://keras.io/examples/generative/vae/
class Sampling(layers.Layer):

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# %%
# from https://keras.io/examples/generative/vae/
class VAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super(VAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(
            name="reconstruction_loss"
        )
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")
        #self.accuracy_tracker = keras.metrics.Accuracy(name = 'accuracy')

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
            #self.accuracy_tracker        
        ]

    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            
            print("reconstruction.shape {} data.shape {}".format(reconstruction.shape, data.shape))

            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum(
                    keras.losses.binary_crossentropy(data, reconstruction), axis=(1, 2)
                )
            )
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var + 1e-7))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            total_loss = reconstruction_loss + kl_loss
            #accuracy = self.accuracy_tracker.result()
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        #self.accuracy_tracker().update_state(accuracy)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
            #"accuracy":self.accuracy_tracker.result()
        }

# %%
latent_dim = 10
vae_filts1 = 100

## Build Encoder
encoder_inputs = keras.Input(shape=(250,1,22))
x = layers.Conv2D(vae_filts1,(10,1),strides = (2,1), activation="relu",padding = 'same')(encoder_inputs)
conv_shape = K.int_shape(x)
x = layers.Flatten()(x)
x = layers.Dense(200,activation = 'relu')(x)
#x = layers.Flatten()(x)
x = layers.Dense(16, activation="relu")(x)

z_mean = layers.Dense(latent_dim, name="z_mean")(x)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(x)
z_log_var += 1e-8
z = Sampling()([z_mean, z_log_var])

encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
encoder.summary()


## Build the decoder
latent_inputs = keras.Input(shape=(latent_dim,))
x = layers.Dense(200,activation = 'relu')(latent_inputs)
x = layers.Dense(conv_shape[1]*conv_shape[2]*conv_shape[3], activation="relu")(x)
x = layers.Reshape((conv_shape[1],conv_shape[2],conv_shape[3]))(x)
decoder_outputs = layers.Conv2DTranspose(22,(10,1),strides=(2,1),activation = 'elu',padding='same')(x)

decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")
decoder.summary()

vae = VAE(encoder, decoder)
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 250, 1, 22)]         0         []
#
#  conv2d (Conv2D)             (None, 125, 1, 100)          22100     ['input_1[0][0]']
#
#  flatten (Flatten)           (None, 12500)                0         ['conv2d[0][0]']
#
#  dense (Dense)               (None, 200)                  2500200   ['flatten[0][0]']
#
#  dense_1 (Dense)             (None, 16)                   3216      ['dense[0][0]']
#
#  z_log_var (Dense)           (None, 10)                   170       ['dense_1[0][0]']
#
#  z_mean (Dense)              (None, 10)                   170       ['dense_1[0][0]']
#
#  tf.__operators__.add (TFOp  (None, 10)                   0         ['z_log_var[0][0]']
#  Lambda)
#
#  sampling (Sampling)         (None, 10)                   0         ['z_mean[0][0]',
#                                                                      'tf.__operators__.add[0][0]']
#
# ==================================================================================================
# Total params: 2525856 (9.64 MB)
# Trainable params: 2525856 (9.64 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 10)]              0
#
#  dense_2 (Dense)             (None, 200)               2200
#
#  dense_3 (Dense)             (None, 12500)             2512500
#
#  reshape (Reshape)           (None, 125, 1, 100)       0
#
#  conv2d_transpose (Conv2DTr  (None, 250, 1, 22)        22022
#  anspose)
#
# =================================================================
# Total params: 2536722 (9.68 MB)
# Trainable params: 2536722 (9.68 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
learning_rate = 1e-3
decay = 1e-6
vae_optimizer = keras.optimizers.legacy.Adam(learning_rate=learning_rate, decay = decay, clipvalue=0.5)
vae.compile(optimizer=vae_optimizer)

vae.fit(x_train, epochs = 30, batch_size=128, verbose = True)
# Out:
# Epoch 1/30
# reconstruction.shape (None, 250, 1, 22) data.shape (None, 250, 1, 22)
# reconstruction.shape (None, 250, 1, 22) data.shape (None, 250, 1, 22)
# 57/57 [==============================] - 2s 35ms/step - loss: 966272542716118827008.0000 - reconstruction_loss: -2465.2368 - kl_loss: 269630967087508750336.0000
# Epoch 2/30
# 57/57 [==============================] - 2s 33ms/step - loss: -5900.8753 - reconstruction_loss: -5980.7041 - kl_loss: 0.0024
# Epoch 3/30
# 57/57 [==============================] - 2s 34ms/step - loss: -6115.5516 - reconstruction_loss: -6123.7549 - kl_loss: 0.0036
# Epoch 4/30
# 57/57 [==============================] - 2s 34ms/step - loss: -6194.3803 - reconstruction_loss: -6148.1616 - kl_loss: 0.0047
# Epoch 5/30
# 57/57 [==============================] - 2s 34ms/step - loss: -6251.9847 - reconstruction_loss: -6119.3813 - kl_loss: 0.0043
# Epoch 6/30
# 57/57 [==============================] - 2s 34ms/step - loss: -6173.1398 - reconstruction_loss: -6117.4692 - kl_loss: 0.0042
# Epoch 7/30
# 57/57 [==============================] - 2s 34ms/step - loss: -6235.4359 - reconstruction_loss: -6139.2427 - kl_loss: 0.0045
# Epoch 8/30
# 57/57 [==============================] - 2s 34ms/step - loss: -6141.7688 - reconstruction_loss: -6174.4517 - kl_loss: 0.0042
# Epoch 9/30
# 57/57 [==============================] - 2s 35ms/step - loss: -6207.9620 - reconstruction_loss: -6170.2017 - kl_loss: 0.0038
# Epoch 10/30
# 57/57 [==============================] - 2s 34ms/step - loss: -6210.7070 - reconstruction_loss: -6163.1333 - kl_loss: 0.0046
# Epoch 11/30
# 57/57 [==============================] - 2s 34ms/step - loss: -6115.0118 - reconstruction_loss: -6189.3145 - kl_loss: 0.0056
# Epoch 12/30
# 57/57 [==============================] - 2s 34ms/step - loss: -6101.6190 - reconstruction_loss: -6151.6465 - kl_loss: 0.0058
# Epoch 13/30
# 57/57 [==============================] - 2s 34ms/step - loss: -6167.0173 - reconstruction_loss: -6136.9541 - kl_loss: 0.0062
# Epoch 14/30
# 57/57 [==============================] - 2s 34ms/step - loss: -6043.4025 - reconstruction_loss: -6169.1792 - kl_loss: 0.0064
# Epoch 15/30
# 57/57 [==============================] - 2s 34ms/step - loss: -6174.2424 - reconstruction_loss: -6160.5083 - kl_loss: 0.0060
# Epoch 16/30
# 57/57 [==============================] - 2s 34ms/step - loss: -6192.9962 - reconstruction_loss: -6123.1729 - kl_loss: 0.0068
# Epoch 17/30
# 57/57 [==============================] - 2s 34ms/step - loss: -6198.6176 - reconstruction_loss: -6138.3584 - kl_loss: 0.0063
# Epoch 18/30
# 57/57 [==============================] - 2s 37ms/step - loss: -6146.8569 - reconstruction_loss: -6144.8213 - kl_loss: 0.0062
# Epoch 19/30
# 57/57 [==============================] - 2s 34ms/step - loss: -6087.8347 - reconstruction_loss: -6151.1484 - kl_loss: 0.0066
# Epoch 20/30
# 57/57 [==============================] - 2s 35ms/step - loss: -6056.2962 - reconstruction_loss: -6164.7373 - kl_loss: 0.0069
# Epoch 21/30
# 57/57 [==============================] - 2s 36ms/step - loss: -6218.1322 - reconstruction_loss: -6160.9604 - kl_loss: 0.0063
# Epoch 22/30
# 57/57 [==============================] - 2s 34ms/step - loss: -6177.1632 - reconstruction_loss: -6193.1475 - kl_loss: 0.0077
# Epoch 23/30
# 57/57 [==============================] - 2s 35ms/step - loss: -6201.4254 - reconstruction_loss: -6165.7563 - kl_loss: 0.0085
# Epoch 24/30
# 57/57 [==============================] - 2s 35ms/step - loss: -6168.3472 - reconstruction_loss: -6160.4697 - kl_loss: 0.0090
# Epoch 25/30
# 57/57 [==============================] - 2s 36ms/step - loss: -6150.5318 - reconstruction_loss: -6153.4878 - kl_loss: 0.0081
# Epoch 26/30
# 57/57 [==============================] - 2s 35ms/step - loss: -6033.4531 - reconstruction_loss: -6167.3232 - kl_loss: 0.0073
# Epoch 27/30
# 57/57 [==============================] - 2s 37ms/step - loss: -6168.9149 - reconstruction_loss: -6165.7651 - kl_loss: 0.0079
# Epoch 28/30
# 57/57 [==============================] - 2s 37ms/step - loss: -6224.6715 - reconstruction_loss: -6201.4395 - kl_loss: 0.0096
# Epoch 29/30
# 57/57 [==============================] - 2s 35ms/step - loss: -6181.3511 - reconstruction_loss: -6158.0967 - kl_loss: 0.0115
# Epoch 30/30
# 57/57 [==============================] - 2s 36ms/step - loss: -6232.0443 - reconstruction_loss: -6169.8491 - kl_loss: 0.0130

# %%
#Passing real data through VAE to generate "fake" data
z_sample = vae.encoder([x_train])[2]
x_decoded = vae.decoder([z_sample])

# %%
# print(x_train)
x_tane = tf.reshape(x_train, (x_train.shape[0], 250, 22))
print('Before VAE')
plt.plot(x_tane[7])
plt.show()

print('After VAE:')
x_vae = np.array(x_decoded).reshape(x_decoded.shape[0], 250, 22)
plt.plot(x_vae[1])
plt.show()

#Adding fake image data to existing real data
x_train3 = np.concatenate((x_train, x_decoded), axis = 0)
y_train3 = np.concatenate((y_train, y_train), axis = 0)
# Out:
# Before VAE
# After VAE:

# %%
# print("x_train3.shape: {}", format(x_train3.shape))

# x_train_transposed = tf.transpose(tf.expand_dims(x_train3, axis=-1), perm=[0, 1, 3, 2])
# x_valid_transposed = tf.transpose(tf.expand_dims(x_valid, axis=-1), perm=[0, 1, 3, 2])
# x_test_transposed = tf.transpose(tf.expand_dims(x_test, axis=-1), perm=[0, 1, 3, 2])

input_shape = x_train3.shape
print("x_train3.shape: {}", format(x_train3.shape))

config = {
    # Network
    'num_inputs': input_shape[0],
    'input_shape': (input_shape[1], 1, input_shape[3]), # (250, 1, 22)
    'epochs': 100,
    'dropout': 0.5,
    'batch_size': 64
}
model = CNN4LayerGRU()
model.build_model(config)
history = model.train(x_train3, y_train3, x_valid, y_valid, config, get_workpath('CNN4LayerGRU'))

raw = model.evaluate(x_test, y_test)
print("Raw Acc result: {}".format(raw[1]))
# Out:
# x_train3.shape: {} (14382, 250, 1, 22)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 250, 1, 25)        13775
#
#  max_pooling2d (MaxPooling2  (None, 84, 1, 25)         0
#  D)
#
#  batch_normalization (Batch  (None, 84, 1, 25)         100
#  Normalization)
#
#  dropout (Dropout)           (None, 84, 1, 25)         0
#
#  conv2d_2 (Conv2D)           (None, 84, 1, 50)         31300
#
#  max_pooling2d_1 (MaxPoolin  (None, 28, 1, 50)         0
#  g2D)
#
#  batch_normalization_1 (Bat  (None, 28, 1, 50)         200
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 28, 1, 50)         0
#
#  conv2d_3 (Conv2D)           (None, 28, 1, 100)        125100
#
#  max_pooling2d_2 (MaxPoolin  (None, 10, 1, 100)        0
#  g2D)
#
#  batch_normalization_2 (Bat  (None, 10, 1, 100)        400
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 10, 1, 100)        0
#
#  conv2d_4 (Conv2D)           (None, 10, 1, 200)        500200
#
#  max_pooling2d_3 (MaxPoolin  (None, 4, 1, 200)         0
#  g2D)
#
#  batch_normalization_3 (Bat  (None, 4, 1, 200)         800
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 4, 1, 200)         0
#
#  flatten_1 (Flatten)         (None, 800)               0
#
#  reshape_1 (Reshape)         (None, 200, 4)            0
#
#  gru (GRU)                   (None, 200, 44)           6600
#
#  dropout_4 (Dropout)         (None, 200, 44)           0
#
#  flatten_2 (Flatten)         (None, 8800)              0
#
#  dense_4 (Dense)             (None, 64)                563264
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 1241999 (4.74 MB)
# Trainable params: 1241249 (4.73 MB)
# Non-trainable params: 750 (2.93 KB)
# _________________________________________________________________
# Model compiled.
# Epoch 1/100
# 225/225 [==============================] - 16s 68ms/step - loss: 1.6768 - accuracy: 0.2792 - val_loss: 1.3533 - val_accuracy: 0.3861
# Epoch 2/100
# 225/225 [==============================] - 16s 71ms/step - loss: 1.3450 - accuracy: 0.3280 - val_loss: 1.2300 - val_accuracy: 0.4641
# Epoch 3/100
# 225/225 [==============================] - 16s 69ms/step - loss: 1.3168 - accuracy: 0.3495 - val_loss: 1.1951 - val_accuracy: 0.4752
# Epoch 4/100
# 225/225 [==============================] - 15s 68ms/step - loss: 1.3032 - accuracy: 0.3570 - val_loss: 1.1801 - val_accuracy: 0.4972
# Epoch 5/100
# 225/225 [==============================] - 15s 65ms/step - loss: 1.2835 - accuracy: 0.3710 - val_loss: 1.1322 - val_accuracy: 0.5264
# Epoch 6/100
# 225/225 [==============================] - 15s 65ms/step - loss: 1.2752 - accuracy: 0.3817 - val_loss: 1.0948 - val_accuracy: 0.5335
# Epoch 7/100
# 225/225 [==============================] - 15s 65ms/step - loss: 1.2576 - accuracy: 0.3945 - val_loss: 1.0475 - val_accuracy: 0.5650
# Epoch 8/100
# 225/225 [==============================] - 15s 68ms/step - loss: 1.2526 - accuracy: 0.3935 - val_loss: 1.0068 - val_accuracy: 0.6154
# Epoch 9/100
# 225/225 [==============================] - 15s 69ms/step - loss: 1.2329 - accuracy: 0.4011 - val_loss: 1.0048 - val_accuracy: 0.5934
# Epoch 10/100
# 225/225 [==============================] - 15s 67ms/step - loss: 1.2254 - accuracy: 0.4083 - val_loss: 0.9635 - val_accuracy: 0.6241
# Epoch 11/100
# 225/225 [==============================] - 14s 64ms/step - loss: 1.2133 - accuracy: 0.4192 - val_loss: 0.9802 - val_accuracy: 0.6367
# Epoch 12/100
# 225/225 [==============================] - 14s 64ms/step - loss: 1.2075 - accuracy: 0.4213 - val_loss: 0.9084 - val_accuracy: 0.6580
# Epoch 13/100
# 225/225 [==============================] - 15s 66ms/step - loss: 1.1964 - accuracy: 0.4254 - val_loss: 0.9092 - val_accuracy: 0.6596
# Epoch 14/100
# 225/225 [==============================] - 15s 65ms/step - loss: 1.1893 - accuracy: 0.4273 - val_loss: 0.8515 - val_accuracy: 0.6911
# Epoch 15/100
# 225/225 [==============================] - 14s 64ms/step - loss: 1.1868 - accuracy: 0.4273 - val_loss: 0.8664 - val_accuracy: 0.6738
# Epoch 16/100
# 225/225 [==============================] - 14s 62ms/step - loss: 1.1787 - accuracy: 0.4388 - val_loss: 0.8206 - val_accuracy: 0.7124
# Epoch 17/100
# 225/225 [==============================] - 15s 65ms/step - loss: 1.1736 - accuracy: 0.4358 - val_loss: 0.8362 - val_accuracy: 0.7069
# Epoch 18/100
# 225/225 [==============================] - 14s 64ms/step - loss: 1.1658 - accuracy: 0.4467 - val_loss: 0.7856 - val_accuracy: 0.7006
# Epoch 19/100
# 225/225 [==============================] - 14s 63ms/step - loss: 1.1593 - accuracy: 0.4463 - val_loss: 0.7759 - val_accuracy: 0.7305
# Epoch 20/100
# 225/225 [==============================] - 14s 63ms/step - loss: 1.1564 - accuracy: 0.4479 - val_loss: 0.7698 - val_accuracy: 0.7305
# Epoch 21/100
# 225/225 [==============================] - 14s 64ms/step - loss: 1.1481 - accuracy: 0.4510 - val_loss: 0.7337 - val_accuracy: 0.7360
# Epoch 22/100
# 225/225 [==============================] - 14s 64ms/step - loss: 1.1379 - accuracy: 0.4579 - val_loss: 0.7412 - val_accuracy: 0.7258
# Epoch 23/100
# 225/225 [==============================] - 14s 63ms/step - loss: 1.1363 - accuracy: 0.4549 - val_loss: 0.7094 - val_accuracy: 0.7352
# Epoch 24/100
# 225/225 [==============================] - 14s 63ms/step - loss: 1.1394 - accuracy: 0.4538 - val_loss: 0.7339 - val_accuracy: 0.7313
# Epoch 25/100
# 225/225 [==============================] - 14s 62ms/step - loss: 1.1335 - accuracy: 0.4591 - val_loss: 0.7174 - val_accuracy: 0.7565
# Epoch 26/100
# 225/225 [==============================] - 14s 64ms/step - loss: 1.1346 - accuracy: 0.4556 - val_loss: 0.6705 - val_accuracy: 0.7699
# Epoch 27/100
# 225/225 [==============================] - 14s 61ms/step - loss: 1.1266 - accuracy: 0.4597 - val_loss: 0.6914 - val_accuracy: 0.7447
# Epoch 28/100
# 225/225 [==============================] - 14s 62ms/step - loss: 1.1279 - accuracy: 0.4558 - val_loss: 0.6906 - val_accuracy: 0.7738
# Epoch 29/100
# 225/225 [==============================] - 14s 62ms/step - loss: 1.1238 - accuracy: 0.4611 - val_loss: 0.6396 - val_accuracy: 0.7857
# Epoch 30/100
# 225/225 [==============================] - 14s 62ms/step - loss: 1.1177 - accuracy: 0.4675 - val_loss: 0.6780 - val_accuracy: 0.7400
# Epoch 31/100
# 225/225 [==============================] - 14s 64ms/step - loss: 1.1129 - accuracy: 0.4715 - val_loss: 0.7035 - val_accuracy: 0.7494
# Epoch 32/100
# 225/225 [==============================] - 14s 63ms/step - loss: 1.1170 - accuracy: 0.4686 - val_loss: 0.7020 - val_accuracy: 0.7368
# Epoch 33/100
# 225/225 [==============================] - 14s 64ms/step - loss: 1.1131 - accuracy: 0.4635 - val_loss: 0.6742 - val_accuracy: 0.7723
# Epoch 34/100
# 225/225 [==============================] - 15s 65ms/step - loss: 1.1099 - accuracy: 0.4732 - val_loss: 0.6579 - val_accuracy: 0.7730
# Epoch 35/100
# 225/225 [==============================] - 15s 65ms/step - loss: 1.1057 - accuracy: 0.4695 - val_loss: 0.6198 - val_accuracy: 0.7880
# Epoch 36/100
# 225/225 [==============================] - 14s 63ms/step - loss: 1.1080 - accuracy: 0.4673 - val_loss: 0.6195 - val_accuracy: 0.7912
# Epoch 37/100
# 225/225 [==============================] - 14s 63ms/step - loss: 1.1070 - accuracy: 0.4700 - val_loss: 0.6552 - val_accuracy: 0.7683
# Epoch 38/100
# 225/225 [==============================] - 14s 64ms/step - loss: 1.1005 - accuracy: 0.4693 - val_loss: 0.6376 - val_accuracy: 0.7888
# Epoch 39/100
# 225/225 [==============================] - 14s 62ms/step - loss: 1.0956 - accuracy: 0.4726 - val_loss: 0.6014 - val_accuracy: 0.7809
# Epoch 40/100
# 225/225 [==============================] - 14s 64ms/step - loss: 1.0980 - accuracy: 0.4755 - val_loss: 0.6297 - val_accuracy: 0.7833
# Epoch 41/100
# 225/225 [==============================] - 14s 62ms/step - loss: 1.0904 - accuracy: 0.4772 - val_loss: 0.5995 - val_accuracy: 0.7943
# Epoch 42/100
# 225/225 [==============================] - 14s 64ms/step - loss: 1.0938 - accuracy: 0.4783 - val_loss: 0.5920 - val_accuracy: 0.7967
# Epoch 43/100
# 225/225 [==============================] - 14s 62ms/step - loss: 1.0930 - accuracy: 0.4759 - val_loss: 0.6060 - val_accuracy: 0.7920
# Epoch 44/100
# 225/225 [==============================] - 14s 63ms/step - loss: 1.0952 - accuracy: 0.4763 - val_loss: 0.6073 - val_accuracy: 0.7943
# Epoch 45/100
# 225/225 [==============================] - 14s 63ms/step - loss: 1.0980 - accuracy: 0.4698 - val_loss: 0.6068 - val_accuracy: 0.7864
# Epoch 46/100
# 225/225 [==============================] - 15s 65ms/step - loss: 1.0909 - accuracy: 0.4825 - val_loss: 0.6030 - val_accuracy: 0.7896
# Epoch 47/100
# 225/225 [==============================] - 14s 63ms/step - loss: 1.0908 - accuracy: 0.4743 - val_loss: 0.6257 - val_accuracy: 0.7928
# Epoch 48/100
# 225/225 [==============================] - 14s 63ms/step - loss: 1.0896 - accuracy: 0.4711 - val_loss: 0.5649 - val_accuracy: 0.8172
# Epoch 49/100
# 225/225 [==============================] - 14s 63ms/step - loss: 1.0886 - accuracy: 0.4805 - val_loss: 0.5630 - val_accuracy: 0.8156
# Epoch 50/100
# 225/225 [==============================] - 15s 65ms/step - loss: 1.0932 - accuracy: 0.4729 - val_loss: 0.6114 - val_accuracy: 0.8188
# Epoch 51/100
# 225/225 [==============================] - 14s 62ms/step - loss: 1.0852 - accuracy: 0.4709 - val_loss: 0.5491 - val_accuracy: 0.8195
# Epoch 52/100
# 225/225 [==============================] - 14s 63ms/step - loss: 1.0832 - accuracy: 0.4774 - val_loss: 0.5751 - val_accuracy: 0.8203
# Epoch 53/100
# 225/225 [==============================] - 14s 63ms/step - loss: 1.0789 - accuracy: 0.4816 - val_loss: 0.5438 - val_accuracy: 0.8251
# Epoch 54/100
# 225/225 [==============================] - 14s 63ms/step - loss: 1.0672 - accuracy: 0.4892 - val_loss: 0.5529 - val_accuracy: 0.8219
# Epoch 55/100
# 225/225 [==============================] - 14s 64ms/step - loss: 1.0808 - accuracy: 0.4831 - val_loss: 0.5423 - val_accuracy: 0.8282
# Epoch 56/100
# 225/225 [==============================] - 14s 63ms/step - loss: 1.0764 - accuracy: 0.4821 - val_loss: 0.5695 - val_accuracy: 0.8148
# Epoch 57/100
# 225/225 [==============================] - 14s 63ms/step - loss: 1.0722 - accuracy: 0.4870 - val_loss: 0.5252 - val_accuracy: 0.8227
# Epoch 58/100
# 225/225 [==============================] - 14s 64ms/step - loss: 1.0721 - accuracy: 0.4871 - val_loss: 0.5301 - val_accuracy: 0.8227
# Epoch 59/100
# 225/225 [==============================] - 14s 64ms/step - loss: 1.0748 - accuracy: 0.4793 - val_loss: 0.5394 - val_accuracy: 0.8282
# Epoch 60/100
# 225/225 [==============================] - 14s 63ms/step - loss: 1.0659 - accuracy: 0.4863 - val_loss: 0.5491 - val_accuracy: 0.8400
# Epoch 61/100
# 225/225 [==============================] - 14s 62ms/step - loss: 1.0732 - accuracy: 0.4889 - val_loss: 0.5540 - val_accuracy: 0.8227
# Epoch 62/100
# 225/225 [==============================] - 14s 62ms/step - loss: 1.0653 - accuracy: 0.4866 - val_loss: 0.5359 - val_accuracy: 0.8392
# Epoch 63/100
# 225/225 [==============================] - 14s 64ms/step - loss: 1.0678 - accuracy: 0.4877 - val_loss: 0.5635 - val_accuracy: 0.8243
# Epoch 64/100
# 225/225 [==============================] - 14s 64ms/step - loss: 1.0607 - accuracy: 0.4914 - val_loss: 0.5301 - val_accuracy: 0.8345
# Epoch 65/100
# 225/225 [==============================] - 14s 64ms/step - loss: 1.0591 - accuracy: 0.4908 - val_loss: 0.5496 - val_accuracy: 0.8314
# Epoch 66/100
# 225/225 [==============================] - 14s 62ms/step - loss: 1.0662 - accuracy: 0.4826 - val_loss: 0.4827 - val_accuracy: 0.8455
# Epoch 67/100
# 225/225 [==============================] - 14s 63ms/step - loss: 1.0628 - accuracy: 0.4898 - val_loss: 0.5456 - val_accuracy: 0.8392
# Epoch 68/100
# 225/225 [==============================] - 14s 64ms/step - loss: 1.0641 - accuracy: 0.4873 - val_loss: 0.5158 - val_accuracy: 0.8251
# Epoch 69/100
# 225/225 [==============================] - 14s 63ms/step - loss: 1.0566 - accuracy: 0.4964 - val_loss: 0.5353 - val_accuracy: 0.8329
# Epoch 70/100
# 225/225 [==============================] - 14s 62ms/step - loss: 1.0632 - accuracy: 0.4901 - val_loss: 0.5137 - val_accuracy: 0.8392
# Epoch 71/100
# 225/225 [==============================] - 14s 62ms/step - loss: 1.0665 - accuracy: 0.4835 - val_loss: 0.4993 - val_accuracy: 0.8345
# Epoch 72/100
# 225/225 [==============================] - 14s 63ms/step - loss: 1.0530 - accuracy: 0.4931 - val_loss: 0.4866 - val_accuracy: 0.8408
# Epoch 73/100
# 225/225 [==============================] - 14s 62ms/step - loss: 1.0612 - accuracy: 0.4899 - val_loss: 0.5441 - val_accuracy: 0.8243
# Epoch 74/100
# 225/225 [==============================] - 14s 62ms/step - loss: 1.0576 - accuracy: 0.4915 - val_loss: 0.4930 - val_accuracy: 0.8266
# Epoch 75/100
# 225/225 [==============================] - 15s 65ms/step - loss: 1.0576 - accuracy: 0.4895 - val_loss: 0.4890 - val_accuracy: 0.8463
# Epoch 76/100
# 225/225 [==============================] - 15s 67ms/step - loss: 1.0573 - accuracy: 0.4885 - val_loss: 0.4721 - val_accuracy: 0.8432
# Epoch 77/100
# 225/225 [==============================] - 14s 64ms/step - loss: 1.0600 - accuracy: 0.4866 - val_loss: 0.5256 - val_accuracy: 0.8440
# Epoch 78/100
# 225/225 [==============================] - 14s 64ms/step - loss: 1.0499 - accuracy: 0.4942 - val_loss: 0.5079 - val_accuracy: 0.8605
# Epoch 79/100
# 225/225 [==============================] - 14s 64ms/step - loss: 1.0512 - accuracy: 0.4857 - val_loss: 0.5043 - val_accuracy: 0.8266
# Epoch 80/100
# 225/225 [==============================] - 14s 63ms/step - loss: 1.0494 - accuracy: 0.4930 - val_loss: 0.5135 - val_accuracy: 0.8479
# Epoch 81/100
# 225/225 [==============================] - 14s 63ms/step - loss: 1.0515 - accuracy: 0.4908 - val_loss: 0.4855 - val_accuracy: 0.8448
# Epoch 82/100
# 225/225 [==============================] - 14s 62ms/step - loss: 1.0549 - accuracy: 0.4855 - val_loss: 0.4887 - val_accuracy: 0.8534
# Epoch 83/100
# 225/225 [==============================] - 14s 63ms/step - loss: 1.0476 - accuracy: 0.4963 - val_loss: 0.4996 - val_accuracy: 0.8369
# Epoch 84/100
# 225/225 [==============================] - 14s 63ms/step - loss: 1.0475 - accuracy: 0.4965 - val_loss: 0.4764 - val_accuracy: 0.8582
# Epoch 85/100
# 225/225 [==============================] - 14s 62ms/step - loss: 1.0484 - accuracy: 0.4895 - val_loss: 0.4713 - val_accuracy: 0.8597
# Epoch 86/100
# 225/225 [==============================] - 14s 64ms/step - loss: 1.0473 - accuracy: 0.4906 - val_loss: 0.4920 - val_accuracy: 0.8613
# Epoch 87/100
# 225/225 [==============================] - 14s 63ms/step - loss: 1.0487 - accuracy: 0.4909 - val_loss: 0.4346 - val_accuracy: 0.8613
# Epoch 88/100
# 225/225 [==============================] - 14s 64ms/step - loss: 1.0397 - accuracy: 0.5009 - val_loss: 0.4480 - val_accuracy: 0.8495
# Epoch 89/100
# 225/225 [==============================] - 14s 63ms/step - loss: 1.0417 - accuracy: 0.4910 - val_loss: 0.4575 - val_accuracy: 0.8597
# Epoch 90/100
# 225/225 [==============================] - 14s 64ms/step - loss: 1.0377 - accuracy: 0.5003 - val_loss: 0.4814 - val_accuracy: 0.8519
# Epoch 91/100
# 225/225 [==============================] - 14s 64ms/step - loss: 1.0420 - accuracy: 0.4942 - val_loss: 0.4751 - val_accuracy: 0.8574
# Epoch 92/100
# 225/225 [==============================] - 14s 63ms/step - loss: 1.0431 - accuracy: 0.4944 - val_loss: 0.4884 - val_accuracy: 0.8589
# Epoch 93/100
# 225/225 [==============================] - 14s 64ms/step - loss: 1.0437 - accuracy: 0.4969 - val_loss: 0.4676 - val_accuracy: 0.8519
# Epoch 94/100
# 225/225 [==============================] - 14s 63ms/step - loss: 1.0398 - accuracy: 0.4987 - val_loss: 0.4567 - val_accuracy: 0.8613
# Epoch 95/100
# 225/225 [==============================] - 14s 64ms/step - loss: 1.0410 - accuracy: 0.4956 - val_loss: 0.4792 - val_accuracy: 0.8542
# Epoch 96/100
# 225/225 [==============================] - 14s 64ms/step - loss: 1.0472 - accuracy: 0.4963 - val_loss: 0.5084 - val_accuracy: 0.8700
# Epoch 97/100
# 225/225 [==============================] - 15s 66ms/step - loss: 1.0445 - accuracy: 0.5016 - val_loss: 0.4569 - val_accuracy: 0.8668
# Epoch 98/100
# 225/225 [==============================] - 15s 65ms/step - loss: 1.0374 - accuracy: 0.4977 - val_loss: 0.4522 - val_accuracy: 0.8613
# Epoch 99/100
# 225/225 [==============================] - 14s 64ms/step - loss: 1.0426 - accuracy: 0.4974 - val_loss: 0.4510 - val_accuracy: 0.8755
# Epoch 100/100
# 225/225 [==============================] - 14s 62ms/step - loss: 1.0479 - accuracy: 0.4925 - val_loss: 0.4404 - val_accuracy: 0.8637
# 56/56 [==============================] - 1s 11ms/step - loss: 0.7580 - accuracy: 0.6975
# Raw Acc result: 0.697516918182373
