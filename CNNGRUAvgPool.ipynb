# %%
import numpy as np
import pandas as pd
import keras
import matplotlib.pyplot as plt

import glob
import random
import datetime
import tensorflow as tf
from shutil import rmtree
from keras.models import load_model
from os.path import join, getctime, basename
from models import *
from utils import *
from data_preprocess import load_prep_data

# %load_ext autoreload
# %autoreload 2

aug_data = load_prep_data(time=500, debug=True, onehot=True)
x_train = aug_data['x_train']
y_train = aug_data['y_train']
x_valid = aug_data['x_valid']
y_valid = aug_data['y_valid']
x_test = aug_data['x_test']
y_test = aug_data['y_test']
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Shape of x_train set: (6960, 22, 250)
# Shape of y_train labels: (6960,)
# Shape of x_valid set: (1500, 22, 250)
# Shape of y_valid labels: (1500,)
# Shape of X_test_prep set: (1772, 22, 250)
# Shape of y_test_prep labels: (1772,)
# Shape of y_train labels after categorical conversion: (6960, 4)
# Shape of y_valid labels after categorical conversion: (1500, 4)
# Shape of y_test labels after categorical conversion: (1772, 4)

# %%
input_shape = x_train.shape
x_train = tf.transpose( tf.expand_dims(x_train, axis=-1), perm=[0, 2, 3, 1])
x_valid = tf.transpose( tf.expand_dims(x_valid, axis=-1), perm=[0, 2, 3, 1])

print("x_train.shape: {}", format(x_train.shape))
# Out:
# x_train.shape: {} (6960, 250, 1, 22)

# %%
config = {
    # Network
    'num_inputs': x_train.shape[0],
    'input_shape': (input_shape[2],1, input_shape[1]),
    'epochs': 100,
    'dropout': 0.6,
    'batch_size': 32
}
ConvGRUAvgPool= ConvGRUAvgPool()
ConvGRUAvgPool.build_model(config)
history = ConvGRUAvgPool.train(x_train, y_train, x_valid, y_valid, config, get_workpath('ConvGRUAvgPool'))
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 250, 1, 25)        13775
#
#  max_pooling2d_6 (MaxPoolin  (None, 84, 1, 25)         0
#  g2D)
#
#  batch_normalization_12 (Ba  (None, 84, 1, 25)         100
#  tchNormalization)
#
#  dropout_12 (Dropout)        (None, 84, 1, 25)         0
#
#  conv2d_13 (Conv2D)          (None, 84, 1, 50)         31300
#
#  average_pooling2d_6 (Avera  (None, 28, 1, 50)         0
#  gePooling2D)
#
#  batch_normalization_13 (Ba  (None, 28, 1, 50)         200
#  tchNormalization)
#
#  dropout_13 (Dropout)        (None, 28, 1, 50)         0
#
#  conv2d_14 (Conv2D)          (None, 28, 1, 100)        125100
#
#  max_pooling2d_7 (MaxPoolin  (None, 10, 1, 100)        0
#  g2D)
#
#  batch_normalization_14 (Ba  (None, 10, 1, 100)        400
#  tchNormalization)
#
#  dropout_14 (Dropout)        (None, 10, 1, 100)        0
#
#  conv2d_15 (Conv2D)          (None, 10, 1, 200)        500200
#
#  average_pooling2d_7 (Avera  (None, 4, 1, 200)         0
#  gePooling2D)
#
#  batch_normalization_15 (Ba  (None, 4, 1, 200)         800
#  tchNormalization)
#
#  dropout_15 (Dropout)        (None, 4, 1, 200)         0
#
#  flatten_3 (Flatten)         (None, 800)               0
#
#  dense_6 (Dense)             (None, 40)                32040
#
#  reshape_3 (Reshape)         (None, 40, 1)             0
#
#  gru_3 (GRU)                 (None, 10)                390
#
#  dense_7 (Dense)             (None, 4)                 44
#
# =================================================================
# Total params:
100
# 218/218 [==============================] - 8s 39ms/step - loss: 0.6830 - accuracy: 0.7402 - val_loss: 0.7351 - val_accuracy: 0.7100
# Epoch 83/100
# 218/218 [==============================] - 8s 39ms/step - loss: 0.6683 - accuracy: 0.7483 - val_loss: 0.7052 - val_accuracy: 0.7307
# Epoch 84/100
# 218/218 [==============================] - 8s 38ms/step - loss: 0.6777 - accuracy: 0.7388 - val_loss: 0.7013 - val_accuracy: 0.7307
# Epoch 85/100
# 218/218 [==============================] - 8s 38ms/step - loss: 0.6808 - accuracy: 0.7434 - val_loss: 0.6973 - val_accuracy: 0.7233
# Epoch 86/100
# 218/218 [==============================] - 9s 40ms/step - loss: 0.6851 - accuracy: 0.7401 - val_loss: 0.6918 - val_accuracy: 0.7407
# Epoch 87/100
# 218/218 [==============================] - 9s 39ms/step - loss: 0.6648 - accuracy: 0.7480 - val_loss: 0.6660 - val_accuracy: 0.7420
# Epoch 88/100
# 218/218 [==============================] - 9s 40ms/step - loss: 0.6517 - accuracy: 0.7549 - val_loss: 0.6903 - val_accuracy: 0.7260
# Epoch 89/100
# 218/218 [==============================] - 9s 40ms/step - loss: 0.6551 - accuracy: 0.7522 - val_loss: 0.6920 - val_accuracy: 0.7320
# Epoch 90/100
# 218/218 [==============================] - 9s 40ms/step - loss: 0.6590 - accuracy: 0.7501 - val_loss: 0.6947 - val_accuracy: 0.7187
# Epoch 91/100
# 218/218 [==============================] - 9s 40ms/step - loss: 0.6614 - accuracy: 0.7451 - val_loss: 0.6869 - val_accuracy: 0.7427
# Epoch 92/100
# 218/218 [==============================] - 10s 45ms/step - loss: 0.6509 - accuracy: 0.7506 - val_loss: 0.6909 - val_accuracy: 0.7400
# Epoch 93/100
# 218/218 [==============================] - 9s 40ms/step - loss: 0.6388 - accuracy: 0.7575 - val_loss: 0.6937 - val_accuracy: 0.7453
# Epoch 94/100
# 218/218 [==============================] - 9s 40ms/step - loss: 0.6545 - accuracy: 0.7513 - val_loss: 0.6657 - val_accuracy: 0.7360
# Epoch 95/100
# 218/218 [==============================] - 9s 41ms/step - loss: 0.6417 - accuracy: 0.7507 - val_loss: 0.6789 - val_accuracy: 0.7380
# Epoch 96/100
# 218/218 [==============================] - 9s 42ms/step - loss: 0.6313 - accuracy: 0.7605 - val_loss: 0.6840 - val_accuracy: 0.7553
# Epoch 97/100
# 218/218 [==============================] - 9s 41ms/step - loss: 0.6378 - accuracy: 0.7591 - val_loss: 0.6871 - val_accuracy: 0.7227
# Epoch 98/100
# 218/218 [==============================] - 9s 41ms/step - loss: 0.6441 - accuracy: 0.7524 - val_loss: 0.7310 - val_accuracy: 0.7120
# Epoch 99/100
# 218/218 [==============================] - 9s 42ms/step - loss: 0.6413 - accuracy: 0.7585 - val_loss: 0.7290 - val_accuracy: 0.7147
# Epoch 100/100
# 218/218 [==============================] - 9s 40ms/step - loss: 0.6289 - accuracy: 0.7593 - val_loss: 0.6874 - val_accuracy: 0.7340

# %%
x_test_transposed = tf.transpose(tf.expand_dims(x_test, axis=-1), perm=[0, 2, 3, 1])
raw = ConvGRUAvgPool.evaluate(x_test_transposed, y_test)
print("Raw Acc result: {}".format(raw[1]))
replace_model_if_better('ConvGRUAvgPool', np.mean(raw[1]), ConvGRUAvgPool, config)
# Out:
# 56/56 [==============================] - 1s 10ms/step - loss: 0.8196 - accuracy: 0.6941
# Raw Acc result: 0.6941308975219727
# Old model exists. Comparing performance.
# New model is worse than the old one. Will not update the old model
# False

# %%
plt.figure(figsize=(6, 4))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.figure(figsize=(6, 4))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
